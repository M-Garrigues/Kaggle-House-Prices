# %%
from sklearn.svm import SVR
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from scipy.stats import norm
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from scipy import stats
from sklearn.linear_model import ElasticNet

# %%
training_data = pd.read_csv("../data/train_1.3.csv")
submission = pd.read_csv("../data/test_1.3.csv")
targets = training_data['SalePrice']
features = training_data.drop('SalePrice', axis = 1)

# %%
train_features, test_features, train_targets, test_targets = train_test_split(features,targets,test_size = 0.2)
model = ElasticNet(random_state = 0)
model.fit(train_features, train_targets)
score = model.score(test_features, test_targets)
# Out:
# C:\Users\Valentin\Anaconda2\envs\python 3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 936111546093.0826, tolerance: 755347844.1352911
#   positive)

# %%
training_data
# Out:
#       1stFlrSF  2ndFlrSF  3SsnPorch  BedroomAbvGr  EnclosedPorch  Fireplaces  \
# 0          856       854          0             3              0           0
# 1         1262         0          0             3              0           1
# 2          920       866          0             3              0           1
# 3          961       756          0             3            272           1
# 4         1145      1053          0             4              0           1
# 5          796       566        320             1              0           0
# 6         1694         0          0             3              0           1
# 7         1107       983          0             3            228           2
# 8         1022       752          0             2            205           2
# 9         1077         0          0             2              0           2
# 10        1040         0          0             3              0           0
# ...

# %%
model.predict(submission).shape
# Out:
# (1458,)

# %%
sub = pd.DataFrame()
sub['Id'] = range(1461,2920)
sub['SalePrice'] = model.predict(submission)
sub.to_csv('../submissions/submission_1.0.csv',index=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-35-8ee73a5a36e7> in <module>
#       1 sub = pd.DataFrame()
#       2 sub['Id'] = range(1461,2920)
# ----> 3 sub['SalePrice'] = model.predict(submission)
#       4 sub.to_csv('../submissions/submission_1.0.csv',index=False)
#
# ~\Anaconda2\envs\python 3\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3368         else:
#    3369             # set column
# -> 3370             self._set_item(key, value)
#    3371
#    3372     def _setitem_slice(self, key, value):
#
# ~\Anaconda2\envs\python 3\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    3443
#    3444         self._ensure_valid_index(value)
# -> 3445         value = self._sanitize_column(key, value)
#    3446         NDFrame._set_item(self, key, value)
#    3447
#
# ...
